# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import torch.optim as optim
from torch.optim.lr_scheduler import ExponentialLR
import datetime
import time
import os
import seaborn as sns
scaler = MinMaxScaler()

# %%
# setting device on GPU if available, else CPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda:0
#
# NVIDIA GeForce GTX 1650
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
def data_pep(df, feat_col_idx, target_col_idx, seq_len=10):
    X_out = []
    y_out = []
    X = df[:, feat_col_idx]
    y = df[:, target_col_idx]

    start_idx = 0
    end_idx = seq_len
    length = len(df)

    while end_idx <= length:
        X_seq = X[start_idx:end_idx].reshape(seq_len, -1, 1)
        y_seq = y[end_idx-1]
        X_out.append(X_seq)
        y_out.append(y_seq)
        start_idx += seq_len
        end_idx += seq_len

    X_out = np.array(X_out)
    y_out = np.array(y_out)
    
    return X_out, y_out

# %%
from torch.utils.data import DataLoader, Dataset

class MyDataset(Dataset):
    def __init__(self, x, y):
        self.x = torch.from_numpy(x).float()
        self.y = torch.from_numpy(y).long()

    def __getitem__(self, index):
        return self.x[index], self.y[index]

    def __len__(self):
        return len(self.x)

# %%
gabor_out = "C:/Users/rezan/Arupreza/Gabor Assets/Gabor_Data/Deep Learning Input/"

# %%
Kia_train_G = pd.read_csv(gabor_out + 'Sonata_train_G____.csv')
Kia_test_G = pd.read_csv(gabor_out + 'Sonata_val_G____.csv')
Kia_val_G = pd.read_csv(gabor_out + 'Sonata_test_G____.csv')

# %%
#Kia_val_G = pd.concat([Kia_train_G[Kia_train_G['Label']==0][:100000], Kia_val_G], ignore_index=True)

# %%
pd.value_counts(Kia_val_G['Label'])
# Out:
# Label
# 0    96930
# 1    96930
# 3    96930
# 2    17025
# Name: count, dtype: int64

# %%
print("Kia_Normal_G Data Shape: ", Kia_train_G.shape)
print("Kia_Fuzz_G Data Shape: ", Kia_test_G.shape)
print("Kia_DoS_G Data Shape: ", Kia_val_G.shape)
# Out:
# Kia_Normal_G Data Shape:  (1436470, 3)
# Kia_Fuzz_G Data Shape:  (307815, 3)
# Kia_DoS_G Data Shape:  (307815, 3)

# %%
X_Kia_train_G, y_Kia_train_G = data_pep(np.array(Kia_train_G), feat_col_idx=[0, 1], target_col_idx=2, seq_len=100)
X_Kia_test_G, y_Kia_test_G = data_pep(np.array(Kia_test_G), feat_col_idx=[0, 1], target_col_idx=2, seq_len=100)
X_Kia_val_G, y_Kia_val_G = data_pep(np.array(Kia_val_G), feat_col_idx=[0, 1], target_col_idx=2, seq_len=100)

# %%
print(X_Kia_train_G[0].shape)
print(y_Kia_train_G[0].shape)

print(X_Kia_test_G[0].shape)
print(y_Kia_test_G[0].shape)

print(X_Kia_val_G[0].shape)
print(y_Kia_val_G[0].shape)
# Out:
# (100, 2, 1)
# ()
# (100, 2, 1)
# ()
# (100, 2, 1)
# ()

# %%
train_dataset = MyDataset(X_Kia_train_G, y_Kia_train_G)
val_dataset = MyDataset(X_Kia_test_G, y_Kia_test_G)
test_dataset = MyDataset(X_Kia_val_G, y_Kia_val_G)

# %%
# Hyper-parameters 
# input_size = 784 # 28x28
num_classes = 4
num_epochs = 100
batch_size = 64
learning_rate = 0.0001

input_size = 2
sequence_length = 100
hidden_size = 128
num_layers = 5

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
# get some random training images
dataiter = iter(train_loader)
sets, labels = next(dataiter)

print(sets[0].shape)
print(sets[0].shape)

print(sets.shape)
print(sets.ndim)
# Out:
# torch.Size([100, 2, 1])
# torch.Size([100, 2, 1])
# torch.Size([64, 100, 2, 1])
# 4

# %%
# Fully connected neural network with one hidden layer
class GRU_Model(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(GRU_Model, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        # -> x needs to be: (batch_size, seq, input_size)
        
        # or:
        #self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        #self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
        
    def forward(self, x):
        # Set initial hidden states (and cell states for LSTM)
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        
        # Forward propagate RNN
        out, _ = self.gru(x, h0)  
        
        # Decode the hidden state of the last time step
        out = out[:, -1, :]
        # out: (n, 128)
         
        out = self.fc(out)
        #out = F.relu(out)
        # out: (n, 10)
        return out

# %%
from torchviz import make_dot

netD = GRU_Model(input_size, hidden_size, num_layers, num_classes)
# Generate a random input tensor with shape (batch_size, sequence_length, input_size)
input_tensor = torch.randn(batch_size, sequence_length, input_size)

# If your model is on GPU, move the input tensor to GPU as well
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
netD = netD.to(device)
input_tensor = input_tensor.to(device)

# Forward pass and visualize
out = netD(input_tensor)
make_dot(out, params=dict(list(netD.named_parameters())))

# %%
model = GRU_Model(input_size, hidden_size, num_layers, num_classes).to(device)

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def train_model(model, train_loader, valid_loader, criterion, optimizer, num_epochs, patience):
    train_losses = []
    valid_losses = []
    best_loss = float('inf')
    best_epoch = 0
    n_no_improvement = 0
    n_total_steps = len(train_loader)
    model_path = 'Sonata_Korea.pt'  # Path to save the model

    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path))

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    for epoch in range(num_epochs):
        # Training
        train_loss = 0.0
        model.train()
        for i, (images, labels) in enumerate(train_loader):
            images = images.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

            if (i + 1) % 100 == 0:
                print(f'Train: Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{n_total_steps}], Loss: {loss.item():.4f}')

        train_loss /= len(train_loader)
        train_losses.append(train_loss)

        # Validation
        valid_loss = 0.0
        model.eval()
        with torch.no_grad():
            for images, labels in valid_loader:
                images = images.reshape(-1, sequence_length, input_size).to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                valid_loss += loss.item()

            valid_loss /= len(valid_loader)
            valid_losses.append(valid_loss)

            print(f'Valid: Epoch [{epoch + 1}/{num_epochs}], Loss: {valid_loss:.4f}')

            if valid_loss < best_loss:
                best_loss = valid_loss
                best_epoch = epoch
                n_no_improvement = 0

                # Save the model
                torch.save(model.state_dict(), model_path)

            else:
                n_no_improvement += 1

            if n_no_improvement >= patience:
                print(f'Early stopping: no improvement for {patience} epochs.')
                break

    return train_losses, valid_losses, best_loss, best_epoch

# %%
#train_losses, valid_losses, best_loss, best_epoch = train_model(model, train_loader, valid_loader, criterion, optimizer, num_epochs=500, patience=20)
# Out:
# Train: Epoch [1/500], Step [100/225], Loss: 1.3410
# Train: Epoch [1/500], Step [200/225], Loss: 1.2463
# Valid: Epoch [1/500], Loss: 1.2443
# Train: Epoch [2/500], Step [100/225], Loss: 0.9418
# Train: Epoch [2/500], Step [200/225], Loss: 0.7117
# Valid: Epoch [2/500], Loss: 0.8055
# Train: Epoch [3/500], Step [100/225], Loss: 0.7279
# Train: Epoch [3/500], Step [200/225], Loss: 0.8170
# Valid: Epoch [3/500], Loss: 0.7769
# Train: Epoch [4/500], Step [100/225], Loss: 0.8496
# Train: Epoch [4/500], Step [200/225], Loss: 0.9998
# Valid: Epoch [4/500], Loss: 0.7677
# Train: Epoch [5/500], Step [100/225], Loss: 0.8209
# Train: Epoch [5/500], Step [200/225], Loss: 0.8471
# Valid: Epoch [5/500], Loss: 0.7587
# Train: Epoch [6/500], Step [100/225], Loss: 0.8515
# Train: Epoch [6/500], Step [200/225], Loss: 0.6981
# Valid: Epoch [6/500], Loss: 0.7488
# Train: Epoch [7/500], Step [100/225], Loss: 0.7748
# Train: Epoch [7/500], Step [200/225], Loss: 0.8070
# Valid: Epoch [7/500], Loss: 0.7368
# Train: Epoch [8/500], Step [100/225], Loss: 0.7679
# Train: Epoch [8/500], Step [200/225], Loss: 0.7190
# Valid: Epoch [8/500], Loss: 0.7347
# Train: Epoch [9/500], Step [100/225], Loss: 0.7331
# Train: Epoch [9/500], Step [200/225], Loss: 0.8480
# Valid: Epoch [9/500], Loss: 0.7511
# Train: Epoch [10/500], Step [100/225], Loss: 0.8121
# Train: Epoch [10/500], Step [200/225], Loss: 0.6629
# Valid: Epoch [10/500], Loss: 0.7295
# Train: Epoch [11/500], Step [100/225], Loss: 0.7835
# Train: Epoch [11/500], Step [200/225], Loss: 0.6904
# Valid: Epoch [11/500], Loss: 0.7369
# Train: Epoch [12/500], Step [100/225], Loss: 0.6559
# Train: Epoch [12/500], Step [200/225], Loss: 0.6937
# Valid: Epoch [12/500], Loss: 0.7195
# Train: Epoch [13/500], Step [100/225], Loss: 0.7774
# Train: Epoch [13/500], Step [200/225], Loss: 0.7271
# Valid: Epoch [13/500], Loss: 0.7207
# Train: Epoch [14/500], Step [100/225], Loss: 0.7887
# Train: Epoch [14/500], Step [200/225], Loss: 0.6024
# Valid: Epoch [14/500], Loss: 0.7197
# Train: Epoch [15/500], Step [100/225], Loss: 0.7578
# Train: Epoch [15/500], Step [200/225], Loss: 0.6081
# Valid: Epoch [15/500], Loss: 0.7146
# Train: Epoch [16/500], Step [100/225], Loss: 0.7644
# Train: Epoch [16/500], Step [200/225], Loss: 0.7942
# Valid: Epoch [16/500], Loss: 0.7071
# Train: Epoch [17/500], Step [100/225], Loss: 0.8141
# Train: Epoch [17/500], Step [200/225], Loss: 0.6709
# Valid: Epoch [17/500], Loss: 0.7028
# Train: Epoch [18/500], Step [100/225], Loss: 0.7438
# Train: Epoch [18/500], Step [200/225], Loss: 0.6935
# Valid: Epoch [18/500], Loss: 0.7639
# Train: Epoch [19/500], Step [100/225], Loss: 0.5689
# Train: Epoch [19/500], Step [200/225], Loss: 0.8305
# Valid: Epoch [19/500], Loss: 0.7017
# Train: Epoch [20/500], Step [100/225], Loss: 0.5444
# Train: Epoch [20/500], Step [200/225], Loss: 0.7843
# Valid: Epoch [20/500], Loss: 0.7027
# Train: Epoch [21/500], Step [100/225], Loss: 0.5686
# Train: Epoch [21/500], Step [200/225], Loss: 0.7343
# Valid: Epoch [21/500], Loss: 0.7279
# Train: Epoch [22/500], Step [100/225], Loss: 0.5871
# Train: Epoch [22/500], Step [200/225], Loss: 0.6033
# Valid: Epoch [22/500], Loss: 0.7032
# Train: Epoch [23/500], Step [100/225], Loss: 0.6421
# Train: Epoch [23/500], Step [200/225], Loss: 0.5877
# Valid: Epoch [23/500], Loss: 0.6835
# Train: Epoch [24/500], Step [100/225], Loss: 0.6968
# Train: Epoch [24/500], Step [200/225], Loss: 0.5587
# Valid: Epoch [24/500], Loss: 0.6837
# Train: Epoch [25/500], Step [100/225], Loss: 0.6155
# Train: Epoch [25/500], Step [200/225], Loss: 0.7688
# Valid: Epoch [25/500], Loss: 0.6809
# Train: Epoch [26/500], Step [100/225], Loss: 0.6574
# Train: Epoch [26/500], Step [200/225], Loss: 0.6525
# Valid: Epoch [26/500], Loss: 0.6924
# Train: Epoch [27/500], Step [100/225], Loss: 0.7870
# Train: Epoch [27/500], Step [200/225], Loss: 0.6284
# Valid: Epoch [27/500], Loss: 0.6879
# Train: Epoch [28/500], Step [100/225], Loss: 0.5556
# Train: Epoch [28/500], Step [200/225], Loss: 0.5688
# Valid: Epoch [28/500], Loss: 0.6864
# Train: Epoch [29/500], Step [100/225], Loss: 0.6541
# Train: Epoch [29/500], Step [200/225], Loss: 0.5902
# Valid: Epoch [29/500], Loss: 0.6722
# Train: Epoch [30/500], Step [100/225], Loss: 0.7120
# Train: Epoch [30/500], Step [200/225], Loss: 0.5621
# Valid: Epoch [30/500], Loss: 0.6604
# Train: Epoch [31/500], Step [100/225], Loss: 0.7534
# Train: Epoch [31/500], Step [200/225], Loss: 0.5847
# Valid: Epoch [31/500], Loss: 0.6609
# Train: Epoch [32/500], Step [100/225], Loss: 0.7532
# Train: Epoch [32/500], Step [200/225], Loss: 0.6718
# Valid: Epoch [32/500], Loss: 0.6496
# Train: Epoch [33/500], Step [100/225], Loss: 0.6498
# Train: Epoch [33/500], Step [200/225], Loss: 0.7075
# Valid: Epoch [33/500], Loss: 0.6379
# Train: Epoch [34/500], Step [100/225], Loss: 0.6868
# Train: Epoch [34/500], Step [200/225], Loss: 0.5966
# Valid: Epoch [34/500], Loss: 0.6492
# Train: Epoch [35/500], Step [100/225], Loss: 0.7927
# Train: Epoch [35/500], Step [200/225], Loss: 0.8781
# Valid: Epoch [35/500], Loss: 0.6348
# Train: Epoch [36/500], Step [100/225], Loss: 0.6176
# Train: Epoch [36/500], Step [200/225], Loss: 0.6917
# Valid: Epoch [36/500], Loss: 0.6301
# Train: Epoch [37/500], Step [100/225], Loss: 0.7162
# Train: Epoch [37/500], Step [200/225], Loss: 0.6404
# Valid: Epoch [37/500], Loss: 0.6391
# Train: Epoch [38/500], Step [100/225], Loss: 0.6229
# Train: Epoch [38/500], Step [200/225], Loss: 0.6413
# Valid: Epoch [38/500], Loss: 0.6207
# Train: Epoch [39/500], Step [100/225], Loss: 0.6759
# Train: Epoch [39/500], Step [200/225], Loss: 0.5364
# Valid: Epoch [39/500], Loss: 0.6230
# Train: Epoch [40/500], Step [100/225], Loss: 0.5921
# Train: Epoch [40/500], Step [200/225], Loss: 0.6008
# Valid: Epoch [40/500], Loss: 0.6261
# Train: Epoch [41/500], Step [100/225], Loss: 0.6048
# Train: Epoch [41/500], Step [200/225], Loss: 0.7746
# Valid: Epoch [41/500], Loss: 0.6598
# Train: Epoch [42/500], Step [100/225], Loss: 0.5918
# Train: Epoch [42/500], Step [200/225], Loss: 0.6740
# Valid: Epoch [42/500], Loss: 0.6197
# Train: Epoch [43/500], Step [100/225], Loss: 0.6866
# Train: Epoch [43/500], Step [200/225], Loss: 0.6417
# Valid: Epoch [43/500], Loss: 0.6133
# Train: Epoch [44/500], Step [100/225], Loss: 0.5433
# Train: Epoch [44/500], Step [200/225], Loss: 0.5792
# Valid: Epoch [44/500], Loss: 0.6037
# Train: Epoch [45/500], Step [100/225], Loss: 0.5894
# Train: Epoch [45/500], Step [200/225], Loss: 0.8044
# Valid: Epoch [45/500], Loss: 0.6242
# Train: Epoch [46/500], Step [100/225], Loss: 0.5935
# Train: Epoch [46/500], Step [200/225], Loss: 0.6841
# Valid: Epoch [46/500], Loss: 0.6034
# Train: Epoch [47/500], Step [100/225], Loss: 0.5530
# Train: Epoch [47/500], Step [200/225], Loss: 0.5889
# Valid: Epoch [47/500], Loss: 0.6082
# Train: Epoch [48/500], Step [100/225], Loss: 0.6189
# Train: Epoch [48/500], Step [200/225], Loss: 0.6151
# Valid: Epoch [48/500], Loss: 0.5945
# Train: Epoch [49/500], Step [100/225], Loss: 0.6302
# Train: Epoch [49/500], Step [200/225], Loss: 0.6722
# Valid: Epoch [49/500], Loss: 0.6726
# Train: Epoch [50/500], Step [100/225], Loss: 0.7063
# Train: Epoch [50/500], Step [200/225], Loss: 0.6186
# Valid: Epoch [50/500], Loss: 0.5994
# Train: Epoch [51/500], Step [100/225], Loss: 0.5605
# Train: Epoch [51/500], Step [200/225], Loss: 0.7647
# Valid: Epoch [51/500], Loss: 0.6103
# Train: Epoch [52/500], Step [100/225], Loss: 0.6011
# Train: Epoch [52/500], Step [200/225], Loss: 0.5853
# Valid: Epoch [52/500], Loss: 0.5991
# Train: Epoch [53/500], Step [100/225], Loss: 0.5729
# Train: Epoch [53/500], Step [200/225], Loss: 0.7286
# Valid: Epoch [53/500], Loss: 0.5886
# Train: Epoch [54/500], Step [100/225], Loss: 0.6010
# Train: Epoch [54/500], Step [200/225], Loss: 0.5169
# Valid: Epoch [54/500], Loss: 0.5867
# Train: Epoch [55/500], Step [100/225], Loss: 0.4172
# Train: Epoch [55/500], Step [200/225], Loss: 0.5317
# Valid: Epoch [55/500], Loss: 0.6000
# Train: Epoch [56/500], Step [100/225], Loss: 0.6884
# Train: Epoch [56/500], Step [200/225], Loss: 0.8468
# Valid: Epoch [56/500], Loss: 0.5711
# Train: Epoch [57/500], Step [100/225], Loss: 0.6014
# Train: Epoch [57/500], Step [200/225], Loss: 0.5329
# Valid: Epoch [57/500], Loss: 0.5937
# Train: Epoch [58/500], Step [100/225], Loss: 0.6101
# Train: Epoch [58/500], Step [200/225], Loss: 0.8036
# Valid: Epoch [58/500], Loss: 0.5629
# Train: Epoch [59/500], Step [100/225], Loss: 0.5755
# Train: Epoch [59/500], Step [200/225], Loss: 0.6756
# Valid: Epoch [59/500], Loss: 0.5459
# Train: Epoch [60/500], Step [100/225], Loss: 0.3923
# Train: Epoch [60/500], Step [200/225], Loss: 0.9376
# Valid: Epoch [60/500], Loss: 0.5412
# Train: Epoch [61/500], Step [100/225], Loss: 0.5731
# Train: Epoch [61/500], Step [200/225], Loss: 0.6347
# Valid: Epoch [61/500], Loss: 0.5118
# Train: Epoch [62/500], Step [100/225], Loss: 0.5731
# Train: Epoch [62/500], Step [200/225], Loss: 0.5605
# Valid: Epoch [62/500], Loss: 0.5536
# Train: Epoch [63/500], Step [100/225], Loss: 0.7522
# Train: Epoch [63/500], Step [200/225], Loss: 0.6389
# Valid: Epoch [63/500], Loss: 0.6706
# Train: Epoch [64/500], Step [100/225], Loss: 0.5378
# Train: Epoch [64/500], Step [200/225], Loss: 0.5849
# Valid: Epoch [64/500], Loss: 0.5337
# Train: Epoch [65/500], Step [100/225], Loss: 0.6246
# Train: Epoch [65/500], Step [200/225], Loss: 0.6005
# Valid: Epoch [65/500], Loss: 0.5110
# Train: Epoch [66/500], Step [100/225], Loss: 0.5845
# Train: Epoch [66/500], Step [200/225], Loss: 0.4143
# Valid: Epoch [66/500], Loss: 0.5403
# Train: Epoch [67/500], Step [100/225], Loss: 0.5597
# Train: Epoch [67/500], Step [200/225], Loss: 0.4850
# Valid: Epoch [67/500], Loss: 0.5249
# Train: Epoch [68/500], Step [100/225], Loss: 0.6020
# Train: Epoch [68/500], Step [200/225], Loss: 0.6301
# Valid: Epoch [68/500], Loss: 0.5098
# Train: Epoch [69/500], Step [100/225], Loss: 0.6410
# Train: Epoch [69/500], Step [200/225], Loss: 0.5910
# Valid: Epoch [69/500], Loss: 0.5037
# Train: Epoch [70/500], Step [100/225], Loss: 0.4500
# Train: Epoch [70/500], Step [200/225], Loss: 0.4117
# Valid: Epoch [70/500], Loss: 0.4824
# Train: Epoch [71/500], Step [100/225], Loss: 0.4857
# Train: Epoch [71/500], Step [200/225], Loss: 0.3676
# Valid: Epoch [71/500], Loss: 0.5060
# Train: Epoch [72/500], Step [100/225], Loss: 0.5046
# Train: Epoch [72/500], Step [200/225], Loss: 0.5170
# Valid: Epoch [72/500], Loss: 0.5411
# Train: Epoch [73/500], Step [100/225], Loss: 0.4537
# Train: Epoch [73/500], Step [200/225], Loss: 0.4319
# Valid: Epoch [73/500], Loss: 0.4682
# Train: Epoch [74/500], Step [100/225], Loss: 0.5741
# Train: Epoch [74/500], Step [200/225], Loss: 0.3773
# Valid: Epoch [74/500], Loss: 0.4715
# Train: Epoch [75/500], Step [100/225], Loss: 0.5066
# Train: Epoch [75/500], Step [200/225], Loss: 0.6107
# Valid: Epoch [75/500], Loss: 0.4874
# Train: Epoch [76/500], Step [100/225], Loss: 0.4549
# Train: Epoch [76/500], Step [200/225], Loss: 0.3035
# Valid: Epoch [76/500], Loss: 0.4478
# Train: Epoch [77/500], Step [100/225], Loss: 0.3806
# Train: Epoch [77/500], Step [200/225], Loss: 0.3314
# Valid: Epoch [77/500], Loss: 0.4557
# Train: Epoch [78/500], Step [100/225], Loss: 0.5365
# Train: Epoch [78/500], Step [200/225], Loss: 0.6572
# Valid: Epoch [78/500], Loss: 0.4525
# Train: Epoch [79/500], Step [100/225], Loss: 0.5280
# Train: Epoch [79/500], Step [200/225], Loss: 0.3852
# Valid: Epoch [79/500], Loss: 0.4931
# Train: Epoch [80/500], Step [100/225], Loss: 0.3895
# Train: Epoch [80/500], Step [200/225], Loss: 0.3990
# Valid: Epoch [80/500], Loss: 0.4441
# Train: Epoch [81/500], Step [100/225], Loss: 0.4715
# Train: Epoch [81/500], Step [200/225], Loss: 0.3504
# Valid: Epoch [81/500], Loss: 0.4695
# Train: Epoch [82/500], Step [100/225], Loss: 0.4675
# Train: Epoch [82/500], Step [200/225], Loss: 0.5404
# Valid: Epoch [82/500], Loss: 0.4758
# Train: Epoch [83/500], Step [100/225], Loss: 0.4649
# Train: Epoch [83/500], Step [200/225], Loss: 0.3934
# Valid: Epoch [83/500], Loss: 0.4454
# Train: Epoch [84/500], Step [100/225], Loss: 0.3902
# Train: Epoch [84/500], Step [200/225], Loss: 0.4043
# Valid: Epoch [84/500], Loss: 0.4330
# Train: Epoch [85/500], Step [100/225], Loss: 0.4984
# Train: Epoch [85/500], Step [200/225], Loss: 0.4675
# Valid: Epoch [85/500], Loss: 0.4499
# Train: Epoch [86/500], Step [100/225], Loss: 0.4947
# Train: Epoch [86/500], Step [200/225], Loss: 0.3139
# Valid: Epoch [86/500], Loss: 0.4294
# Train: Epoch [87/500], Step [100/225], Loss: 0.5307
# Train: Epoch [87/500], Step [200/225], Loss: 0.3421
# Valid: Epoch [87/500], Loss: 0.4250
# Train: Epoch [88/500], Step [100/225], Loss: 0.3720
# Train: Epoch [88/500], Step [200/225], Loss: 0.3721
# Valid: Epoch [88/500], Loss: 0.4429
# Train: Epoch [89/500], Step [100/225], Loss: 0.3418
# Train: Epoch [89/500], Step [200/225], Loss: 0.3993
# Valid: Epoch [89/500], Loss: 0.4217
# Train: Epoch [90/500], Step [100/225], Loss: 0.4419
# Train: Epoch [90/500], Step [200/225], Loss: 0.4454
# Valid: Epoch [90/500], Loss: 0.4246
# Train: Epoch [91/500], Step [100/225], Loss: 0.6181
# Train: Epoch [91/500], Step [200/225], Loss: 0.4822
# Valid: Epoch [91/500], Loss: 0.4216
# Train: Epoch [92/500], Step [100/225], Loss: 0.4819
# Train: Epoch [92/500], Step [200/225], Loss: 0.4629
# Valid: Epoch [92/500], Loss: 0.4243
# Train: Epoch [93/500], Step [100/225], Loss: 0.3845
# Train: Epoch [93/500], Step [200/225], Loss: 0.5198
# Valid: Epoch [93/500], Loss: 0.4201
# Train: Epoch [94/500], Step [100/225], Loss: 0.4568
# Train: Epoch [94/500], Step [200/225], Loss: 0.3698
# Valid: Epoch [94/500], Loss: 0.4373
# Train: Epoch [95/500], Step [100/225], Loss: 0.3805
# Train: Epoch [95/500], Step [200/225], Loss: 0.3618
# Valid: Epoch [95/500], Loss: 0.4224
# Train: Epoch [96/500], Step [100/225], Loss: 0.3722
# Train: Epoch [96/500], Step [200/225], Loss: 0.4042
# Valid: Epoch [96/500], Loss: 0.4534
# Train: Epoch [97/500], Step [100/225], Loss: 0.4975
# Train: Epoch [97/500], Step [200/225], Loss: 0.4970
# Valid: Epoch [97/500], Loss: 0.4432
# Train: Epoch [98/500], Step [100/225], Loss: 0.3660
# Train: Epoch [98/500], Step [200/225], Loss: 0.4371
# Valid: Epoch [98/500], Loss: 0.4369
# Train: Epoch [99/500], Step [100/225], Loss: 0.3862
# Train: Epoch [99/500], Step [200/225], Loss: 0.4318
# Valid: Epoch [99/500], Loss: 0.4374
# Train: Epoch [100/500], Step [100/225], Loss: 0.5551
# Train: Epoch [100/500], Step [200/225], Loss: 0.4940
# Valid: Epoch [100/500], Loss: 0.4277
# Train: Epoch [101/500], Step [100/225], Loss: 0.4038
# Train: Epoch [101/500], Step [200/225], Loss: 0.4016
# Valid: Epoch [101/500], Loss: 0.4277
# Train: Epoch [102/500], Step [100/225], Loss: 0.4483
# Train: Epoch [102/500], Step [200/225], Loss: 0.4708
# Valid: Epoch [102/500], Loss: 0.4228
# Train: Epoch [103/500], Step [100/225], Loss: 0.4117
# Train: Epoch [103/500], Step [200/225], Loss: 0.5104
# Valid: Epoch [103/500], Loss: 0.4264
# Train: Epoch [104/500], Step [100/225], Loss: 0.3580
# Train: Epoch [104/500], Step [200/225], Loss: 0.4941
# Valid: Epoch [104/500], Loss: 0.4211
# Train: Epoch [105/500], Step [100/225], Loss: 0.5101
# Train: Epoch [105/500], Step [200/225], Loss: 0.4408
# Valid: Epoch [105/500], Loss: 0.4199
# Train: Epoch [106/500], Step [100/225], Loss: 0.3586
# Train: Epoch [106/500], Step [200/225], Loss: 0.4550
# Valid: Epoch [106/500], Loss: 0.4370
# Train: Epoch [107/500], Step [100/225], Loss: 0.5136
# Train: Epoch [107/500], Step [200/225], Loss: 0.3988
# Valid: Epoch [107/500], Loss: 0.4257
# Train: Epoch [108/500], Step [100/225], Loss: 0.4316
# Train: Epoch [108/500], Step [200/225], Loss: 0.4220
# Valid: Epoch [108/500], Loss: 0.4238
# Train: Epoch [109/500], Step [100/225], Loss: 0.3823
# Train: Epoch [109/500], Step [200/225], Loss: 0.4075
# Valid: Epoch [109/500], Loss: 0.4417
# Train: Epoch [110/500], Step [100/225], Loss: 0.3526
# Train: Epoch [110/500], Step [200/225], Loss: 0.4861
# Valid: Epoch [110/500], Loss: 0.4270
# Train: Epoch [111/500], Step [100/225], Loss: 0.3540
# Train: Epoch [111/500], Step [200/225], Loss: 0.3306
# Valid: Epoch [111/500], Loss: 0.4214
# Train: Epoch [112/500], Step [100/225], Loss: 0.4594
# Train: Epoch [112/500], Step [200/225], Loss: 0.3280
# Valid: Epoch [112/500], Loss: 0.4297
# Train: Epoch [113/500], Step [100/225], Loss: 0.3319
# Train: Epoch [113/500], Step [200/225], Loss: 0.4991
# Valid: Epoch [113/500], Loss: 0.4176
# Train: Epoch [114/500], Step [100/225], Loss: 0.4649
# Train: Epoch [114/500], Step [200/225], Loss: 0.3759
# Valid: Epoch [114/500], Loss: 0.4333
# Train: Epoch [115/500], Step [100/225], Loss: 0.4002
# Train: Epoch [115/500], Step [200/225], Loss: 0.4617
# Valid: Epoch [115/500], Loss: 0.4497
# Train: Epoch [116/500], Step [100/225], Loss: 0.3535
# Train: Epoch [116/500], Step [200/225], Loss: 0.5246
# Valid: Epoch [116/500], Loss: 0.4184
# Train: Epoch [117/500], Step [100/225], Loss: 0.2507
# Train: Epoch [117/500], Step [200/225], Loss: 0.3645
# Valid: Epoch [117/500], Loss: 0.4299
# Train: Epoch [118/500], Step [100/225], Loss: 0.4114
# Train: Epoch [118/500], Step [200/225], Loss: 0.3647
# Valid: Epoch [118/500], Loss: 0.4085
# Train: Epoch [119/500], Step [100/225], Loss: 0.3486
# Train: Epoch [119/500], Step [200/225], Loss: 0.4128
# Valid: Epoch [119/500], Loss: 0.4249
# Train: Epoch [120/500], Step [100/225], Loss: 0.4330
# Train: Epoch [120/500], Step [200/225], Loss: 0.2532
# Valid: Epoch [120/500], Loss: 0.4176
# Train: Epoch [121/500], Step [100/225], Loss: 0.5219
# Train: Epoch [121/500], Step [200/225], Loss: 0.3863
# Valid: Epoch [121/500], Loss: 0.4592
# Train: Epoch [122/500], Step [100/225], Loss: 0.3377
# Train: Epoch [122/500], Step [200/225], Loss: 0.5666
# Valid: Epoch [122/500], Loss: 0.4066
# Train: Epoch [123/500], Step [100/225], Loss: 0.3493
# Train: Epoch [123/500], Step [200/225], Loss: 0.4291
# Valid: Epoch [123/500], Loss: 0.4102
# Train: Epoch [124/500], Step [100/225], Loss: 0.2822
# Train: Epoch [124/500], Step [200/225], Loss: 0.5259
# Valid: Epoch [124/500], Loss: 0.4091
# Train: Epoch [125/500], Step [100/225], Loss: 0.3902
# Train: Epoch [125/500], Step [200/225], Loss: 0.4301
# Valid: Epoch [125/500], Loss: 0.4174
# Train: Epoch [126/500], Step [100/225], Loss: 0.5952
# Train: Epoch [126/500], Step [200/225], Loss: 0.4310
# Valid: Epoch [126/500], Loss: 0.4064
# Train: Epoch [127/500], Step [100/225], Loss: 0.4587
# Train: Epoch [127/500], Step [200/225], Loss: 0.4830
# Valid: Epoch [127/500], Loss: 0.4122
# Train: Epoch [128/500], Step [100/225], Loss: 0.4602
# Train: Epoch [128/500], Step [200/225], Loss: 0.4622
# Valid: Epoch [128/500], Loss: 0.4196
# Train: Epoch [129/500], Step [100/225], Loss: 0.5479
# Train: Epoch [129/500], Step [200/225], Loss: 0.6147
# Valid: Epoch [129/500], Loss: 0.4202
# Train: Epoch [130/500], Step [100/225], Loss: 0.4204
# Train: Epoch [130/500], Step [200/225], Loss: 0.3979
# Valid: Epoch [130/500], Loss: 0.4076
# Train: Epoch [131/500], Step [100/225], Loss: 0.3969
# Train: Epoch [131/500], Step [200/225], Loss: 0.4457
# Valid: Epoch [131/500], Loss: 0.4106
# Train: Epoch [132/500], Step [100/225], Loss: 0.4374
# Train: Epoch [132/500], Step [200/225], Loss: 0.4399
# Valid: Epoch [132/500], Loss: 0.4027
# Train: Epoch [133/500], Step [100/225], Loss: 0.5147
# Train: Epoch [133/500], Step [200/225], Loss: 0.3570
# Valid: Epoch [133/500], Loss: 0.4082
# Train: Epoch [134/500], Step [100/225], Loss: 0.3284
# Train: Epoch [134/500], Step [200/225], Loss: 0.4660
# Valid: Epoch [134/500], Loss: 0.4066
# Train: Epoch [135/500], Step [100/225], Loss: 0.5679
# Train: Epoch [135/500], Step [200/225], Loss: 0.3622
# Valid: Epoch [135/500], Loss: 0.4520
# Train: Epoch [136/500], Step [100/225], Loss: 0.2853
# Train: Epoch [136/500], Step [200/225], Loss: 0.4157
# Valid: Epoch [136/500], Loss: 0.4007
# Train: Epoch [137/500], Step [100/225], Loss: 0.5097
# Train: Epoch [137/500], Step [200/225], Loss: 0.3947
# Valid: Epoch [137/500], Loss: 0.4270
# Train: Epoch [138/500], Step [100/225], Loss: 0.4481
# Train: Epoch [138/500], Step [200/225], Loss: 0.6148
# Valid: Epoch [138/500], Loss: 0.4226
# Train: Epoch [139/500], Step [100/225], Loss: 0.4850
# Train: Epoch [139/500], Step [200/225], Loss: 0.3121
# Valid: Epoch [139/500], Loss: 0.4556
# Train: Epoch [140/500], Step [100/225], Loss: 0.3053
# Train: Epoch [140/500], Step [200/225], Loss: 0.2425
# Valid: Epoch [140/500], Loss: 0.4243
# Train: Epoch [141/500], Step [100/225], Loss: 0.4192
# Train: Epoch [141/500], Step [200/225], Loss: 0.2360
# Valid: Epoch [141/500], Loss: 0.4387
# Train: Epoch [142/500], Step [100/225], Loss: 0.3231
# Train: Epoch [142/500], Step [200/225], Loss: 0.3826
# Valid: Epoch [142/500], Loss: 0.4144
# Train: Epoch [143/500], Step [100/225], Loss: 0.3887
# Train: Epoch [143/500], Step [200/225], Loss: 0.3624
# Valid: Epoch [143/500], Loss: 0.3992
# Train: Epoch [144/500], Step [100/225], Loss: 0.4026
# Train: Epoch [144/500], Step [200/225], Loss: 0.4288
# Valid: Epoch [144/500], Loss: 0.4118
# Train: Epoch [145/500], Step [100/225], Loss: 0.3508
# Train: Epoch [145/500], Step [200/225], Loss: 0.5551
# Valid: Epoch [145/500], Loss: 0.3968
# Train: Epoch [146/500], Step [100/225], Loss: 0.4561
# Train: Epoch [146/500], Step [200/225], Loss: 0.2668
# Valid: Epoch [146/500], Loss: 0.4049
# Train: Epoch [147/500], Step [100/225], Loss: 0.3518
# Train: Epoch [147/500], Step [200/225], Loss: 0.3583
# Valid: Epoch [147/500], Loss: 0.4050
# Train: Epoch [148/500], Step [100/225], Loss: 0.4488
# Train: Epoch [148/500], Step [200/225], Loss: 0.3232
# Valid: Epoch [148/500], Loss: 0.4117
# Train: Epoch [149/500], Step [100/225], Loss: 0.5057
# Train: Epoch [149/500], Step [200/225], Loss: 0.3057
# Valid: Epoch [149/500], Loss: 0.4091
# Train: Epoch [150/500], Step [100/225], Loss: 0.4053
# Train: Epoch [150/500], Step [200/225], Loss: 0.3687
# Valid: Epoch [150/500], Loss: 0.4071
# Train: Epoch [151/500], Step [100/225], Loss: 0.1934
# Train: Epoch [151/500], Step [200/225], Loss: 0.5117
# Valid: Epoch [151/500], Loss: 0.3949
# Train: Epoch [152/500], Step [100/225], Loss: 0.3187
# Train: Epoch [152/500], Step [200/225], Loss: 0.3961
# Valid: Epoch [152/500], Loss: 0.3968
# Train: Epoch [153/500], Step [100/225], Loss: 0.5587
# Train: Epoch [153/500], Step [200/225], Loss: 0.3158
# Valid: Epoch [153/500], Loss: 0.3946
# Train: Epoch [154/500], Step [100/225], Loss: 0.3360
# Train: Epoch [154/500], Step [200/225], Loss: 0.2396
# Valid: Epoch [154/500], Loss: 0.4477
# Train: Epoch [155/500], Step [100/225], Loss: 0.2870
# Train: Epoch [155/500], Step [200/225], Loss: 0.1891
# Valid: Epoch [155/500], Loss: 0.4007
# Train: Epoch [156/500], Step [100/225], Loss: 0.4259
# Train: Epoch [156/500], Step [200/225], Loss: 0.4052
# Valid: Epoch [156/500], Loss: 0.3894
# Train: Epoch [157/500], Step [100/225], Loss: 0.4389
# Train: Epoch [157/500], Step [200/225], Loss: 0.3022
# Valid: Epoch [157/500], Loss: 0.3961
# Train: Epoch [158/500], Step [100/225], Loss: 0.3971
# Train: Epoch [158/500], Step [200/225], Loss: 0.4598
# Valid: Epoch [158/500], Loss: 0.4079
# Train: Epoch [159/500], Step [100/225], Loss: 0.2690
# Train: Epoch [159/500], Step [200/225], Loss: 0.5045
# Valid: Epoch [159/500], Loss: 0.3924
# Train: Epoch [160/500], Step [100/225], Loss: 0.4906
# Train: Epoch [160/500], Step [200/225], Loss: 0.4444
# Valid: Epoch [160/500], Loss: 0.3931
# Train: Epoch [161/500], Step [100/225], Loss: 0.3490
# Train: Epoch [161/500], Step [200/225], Loss: 0.3850
# Valid: Epoch [161/500], Loss: 0.3866
# Train: Epoch [162/500], Step [100/225], Loss: 0.4991
# Train: Epoch [162/500], Step [200/225], Loss: 0.3193
# Valid: Epoch [162/500], Loss: 0.4167
# Train: Epoch [163/500], Step [100/225], Loss: 0.4487
# Train: Epoch [163/500], Step [200/225], Loss: 0.3300
# Valid: Epoch [163/500], Loss: 0.3971
# Train: Epoch [164/500], Step [100/225], Loss: 0.3999
# Train: Epoch [164/500], Step [200/225], Loss: 0.4268
# Valid: Epoch [164/500], Loss: 0.3836
# Train: Epoch [165/500], Step [100/225], Loss: 0.2598
# Train: Epoch [165/500], Step [200/225], Loss: 0.3475
# Valid: Epoch [165/500], Loss: 0.3843
# Train: Epoch [166/500], Step [100/225], Loss: 0.2757
# Train: Epoch [166/500], Step [200/225], Loss: 0.3345
# Valid: Epoch [166/500], Loss: 0.3980
# Train: Epoch [167/500], Step [100/225], Loss: 0.3799
# Train: Epoch [167/500], Step [200/225], Loss: 0.4019
# Valid: Epoch [167/500], Loss: 0.3858
# Train: Epoch [168/500], Step [100/225], Loss: 0.5090
# Train: Epoch [168/500], Step [200/225], Loss: 0.3368
# Valid: Epoch [168/500], Loss: 0.3896
# Train: Epoch [169/500], Step [100/225], Loss: 0.4196
# Train: Epoch [169/500], Step [200/225], Loss: 0.3361
# Valid: Epoch [169/500], Loss: 0.4040
# Train: Epoch [170/500], Step [100/225], Loss: 0.5102
# Train: Epoch [170/500], Step [200/225], Loss: 0.3856
# Valid: Epoch [170/500], Loss: 0.3966
# Train: Epoch [171/500], Step [100/225], Loss: 0.2912
# Train: Epoch [171/500], Step [200/225], Loss: 0.2555
# Valid: Epoch [171/500], Loss: 0.3825
# Train: Epoch [172/500], Step [100/225], Loss: 0.2952
# Train: Epoch [172/500], Step [200/225], Loss: 0.3432
# Valid: Epoch [172/500], Loss: 0.3943
# Train: Epoch [173/500], Step [100/225], Loss: 0.3424
# Train: Epoch [173/500], Step [200/225], Loss: 0.4234
# Valid: Epoch [173/500], Loss: 0.3857
# Train: Epoch [174/500], Step [100/225], Loss: 0.4266
# Train: Epoch [174/500], Step [200/225], Loss: 0.3404
# Valid: Epoch [174/500], Loss: 0.3918
# Train: Epoch [175/500], Step [100/225], Loss: 0.3308
# Train: Epoch [175/500], Step [200/225], Loss: 0.3944
# Valid: Epoch [175/500], Loss: 0.4375
# Train: Epoch [176/500], Step [100/225], Loss: 0.3931
# Train: Epoch [176/500], Step [200/225], Loss: 0.3052
# Valid: Epoch [176/500], Loss: 0.4187
# Train: Epoch [177/500], Step [100/225], Loss: 0.3588
# Train: Epoch [177/500], Step [200/225], Loss: 0.3107
# Valid: Epoch [177/500], Loss: 0.3903
# Train: Epoch [178/500], Step [100/225], Loss: 0.2836
# Train: Epoch [178/500], Step [200/225], Loss: 0.4147
# Valid: Epoch [178/500], Loss: 0.3877
# Train: Epoch [179/500], Step [100/225], Loss: 0.3556
# Train: Epoch [179/500], Step [200/225], Loss: 0.3675
# Valid: Epoch [179/500], Loss: 0.3862
# Train: Epoch [180/500], Step [100/225], Loss: 0.2420
# Train: Epoch [180/500], Step [200/225], Loss: 0.3718
# Valid: Epoch [180/500], Loss: 0.4112
# Train: Epoch [181/500], Step [100/225], Loss: 0.3467
# Train: Epoch [181/500], Step [200/225], Loss: 0.3146
# Valid: Epoch [181/500], Loss: 0.4226
# Train: Epoch [182/500], Step [100/225], Loss: 0.2824
# Train: Epoch [182/500], Step [200/225], Loss: 0.4982
# Valid: Epoch [182/500], Loss: 0.4166
# Train: Epoch [183/500], Step [100/225], Loss: 0.3116
# Train: Epoch [183/500], Step [200/225], Loss: 0.3245
# Valid: Epoch [183/500], Loss: 0.3808
# Train: Epoch [184/500], Step [100/225], Loss: 0.3910
# Train: Epoch [184/500], Step [200/225], Loss: 0.2854
# Valid: Epoch [184/500], Loss: 0.3941
# Train: Epoch [185/500], Step [100/225], Loss: 0.3911
# Train: Epoch [185/500], Step [200/225], Loss: 0.5394
# Valid: Epoch [185/500], Loss: 0.3882
# Train: Epoch [186/500], Step [100/225], Loss: 0.3563
# Train: Epoch [186/500], Step [200/225], Loss: 0.2007
# Valid: Epoch [186/500], Loss: 0.3891
# Train: Epoch [187/500], Step [100/225], Loss: 0.4605
# Train: Epoch [187/500], Step [200/225], Loss: 0.3680
# Valid: Epoch [187/500], Loss: 0.3784
# Train: Epoch [188/500], Step [100/225], Loss: 0.3421
# Train: Epoch [188/500], Step [200/225], Loss: 0.2727
# Valid: Epoch [188/500], Loss: 0.3968
# Train: Epoch [189/500], Step [100/225], Loss: 0.3191
# Train: Epoch [189/500], Step [200/225], Loss: 0.4242
# Valid: Epoch [189/500], Loss: 0.3804
# Train: Epoch [190/500], Step [100/225], Loss: 0.2844
# Train: Epoch [190/500], Step [200/225], Loss: 0.2819
# Valid: Epoch [190/500], Loss: 0.3787
# Train: Epoch [191/500], Step [100/225], Loss: 0.2990
# Train: Epoch [191/500], Step [200/225], Loss: 0.4331
# Valid: Epoch [191/500], Loss: 0.3838
# Train: Epoch [192/500], Step [100/225], Loss: 0.4258
# Train: Epoch [192/500], Step [200/225], Loss: 0.2713
# Valid: Epoch [192/500], Loss: 0.3880
# Train: Epoch [193/500], Step [100/225], Loss: 0.2763
# Train: Epoch [193/500], Step [200/225], Loss: 0.3626
# Valid: Epoch [193/500], Loss: 0.3822
# Train: Epoch [194/500], Step [100/225], Loss: 0.3047
# Train: Epoch [194/500], Step [200/225], Loss: 0.2292
# Valid: Epoch [194/500], Loss: 0.3851
# Train: Epoch [195/500], Step [100/225], Loss: 0.2996
# Train: Epoch [195/500], Step [200/225], Loss: 0.4495
# Valid: Epoch [195/500], Loss: 0.3778
# Train: Epoch [196/500], Step [100/225], Loss: 0.4871
# Train: Epoch [196/500], Step [200/225], Loss: 0.3002
# Valid: Epoch [196/500], Loss: 0.3976
# Train: Epoch [197/500], Step [100/225], Loss: 0.3263
# Train: Epoch [197/500], Step [200/225], Loss: 0.4073
# Valid: Epoch [197/500], Loss: 0.3838
# Train: Epoch [198/500], Step [100/225], Loss: 0.3583
# Train: Epoch [198/500], Step [200/225], Loss: 0.2764
# Valid: Epoch [198/500], Loss: 0.3796
# Train: Epoch [199/500], Step [100/225], Loss: 0.2273
# Train: Epoch [199/500], Step [200/225], Loss: 0.3513
# Valid: Epoch [199/500], Loss: 0.3861
# Train: Epoch [200/500], Step [100/225], Loss: 0.4207
# Train: Epoch [200/500], Step [200/225], Loss: 0.3929
# Valid: Epoch [200/500], Loss: 0.3887
# Train: Epoch [201/500], Step [100/225], Loss: 0.3195
# Train: Epoch [201/500], Step [200/225], Loss: 0.2841
# Valid: Epoch [201/500], Loss: 0.3905
# Train: Epoch [202/500], Step [100/225], Loss: 0.4157
# Train: Epoch [202/500], Step [200/225], Loss: 0.2678
# Valid: Epoch [202/500], Loss: 0.3987
# Train: Epoch [203/500], Step [100/225], Loss: 0.2663
# Train: Epoch [203/500], Step [200/225], Loss: 0.5244
# Valid: Epoch [203/500], Loss: 0.3839
# Train: Epoch [204/500], Step [100/225], Loss: 0.3817
# Train: Epoch [204/500], Step [200/225], Loss: 0.4293
# Valid: Epoch [204/500], Loss: 0.4015
# Train: Epoch [205/500], Step [100/225], Loss: 0.2155
# Train: Epoch [205/500], Step [200/225], Loss: 0.3453
# Valid: Epoch [205/500], Loss: 0.3809
# Train: Epoch [206/500], Step [100/225], Loss: 0.2859
# Train: Epoch [206/500], Step [200/225], Loss: 0.3138
# Valid: Epoch [206/500], Loss: 0.3895
# Train: Epoch [207/500], Step [100/225], Loss: 0.3145
# Train: Epoch [207/500], Step [200/225], Loss: 0.2724
# Valid: Epoch [207/500], Loss: 0.3875
# Train: Epoch [208/500], Step [100/225], Loss: 0.3751
# Train: Epoch [208/500], Step [200/225], Loss: 0.2213
# Valid: Epoch [208/500], Loss: 0.3816
# Train: Epoch [209/500], Step [100/225], Loss: 0.2185
# Train: Epoch [209/500], Step [200/225], Loss: 0.3518
# Valid: Epoch [209/500], Loss: 0.3879
# Train: Epoch [210/500], Step [100/225], Loss: 0.2982
# Train: Epoch [210/500], Step [200/225], Loss: 0.4264
# Valid: Epoch [210/500], Loss: 0.3891
# Train: Epoch [211/500], Step [100/225], Loss: 0.3020
# Train: Epoch [211/500], Step [200/225], Loss: 0.2778
# Valid: Epoch [211/500], Loss: 0.4560
# Train: Epoch [212/500], Step [100/225], Loss: 0.3583
# Train: Epoch [212/500], Step [200/225], Loss: 0.1909
# Valid: Epoch [212/500], Loss: 0.3870
# Train: Epoch [213/500], Step [100/225], Loss: 0.2489
# Train: Epoch [213/500], Step [200/225], Loss: 0.3536
# Valid: Epoch [213/500], Loss: 0.4011
# Train: Epoch [214/500], Step [100/225], Loss: 0.3144
# Train: Epoch [214/500], Step [200/225], Loss: 0.2816
# Valid: Epoch [214/500], Loss: 0.3840
# Train: Epoch [215/500], Step [100/225], Loss: 0.2435
# Train: Epoch [215/500], Step [200/225], Loss: 0.4070
# Valid: Epoch [215/500], Loss: 0.3969
# Early stopping: no improvement for 20 epochs.

# %%
def test_model(model, test_loader):
    model = model.to(device)  # Move the model to the appropriate device
    model.eval()
    with torch.no_grad():
        predictions = []
        labels = []
        for images, batch_labels in test_loader:
            images = images.reshape(-1, sequence_length, input_size).to(device)
            batch_labels = batch_labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            predictions.append(predicted.cpu().numpy())
            labels.append(batch_labels.cpu().numpy())

        predictions = np.concatenate(predictions)
        labels = np.concatenate(labels)
        acc = 100.0 * np.sum(predictions == labels) / len(labels)
        print(f'Accuracy of the network on the test set: {acc:.4f} %')
        return predictions, labels

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GRU_Model(input_size, hidden_size, num_layers, num_classes)
model.load_state_dict(torch.load('Sonata_Korea.pt', map_location=device))

# Move the test_loader to the appropriate device
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
# Replace 'test_dataset' with your actual test dataset

test_predictions, test_labels = test_model(model, test_loader)
# Out:
# Accuracy of the network on the test set: 84.2755 %

# %%
y_pred = test_predictions
y_test = test_labels

# %%
from sklearn.metrics import confusion_matrix

#Get the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print(cf_matrix)
# Out:
# [[836 120   6   7]
#  [ 86 751   5 127]
#  [  5   4 161   0]
#  [ 10 113   1 846]]

# %%
def plot_confusion_matrix_with_percentages(y_test, y_pred, labels):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Convert the counts to percentages along rows (category-wise percentages)
    row_sums = cm.sum(axis=1)
    cm_percentages = cm / row_sums[:, np.newaxis] * 100
    
    # Create a heatmap with seaborn
    plt.figure(figsize=(8, 7))

    # Plot the confusion matrix as a heatmap with annotations for both numbers and percentages
    # Plot the confusion matrix as a heatmap with annotations for both numbers and percentages
    for i in range(len(cm)):
        for j in range(len(cm)):
            # Add actual numbers as text in the center of each cell
            plt.text(j + 0.5, i + 0.5, str(cm[i, j]), ha='center', va='center', fontsize=16, fontweight='bold', color='black')
            # Add percentages as text on top of the actual numbers
            plt.text(j + 0.5, i + 0.65, f'{cm_percentages[i, j]:.2f}%', ha='center', va='center', fontsize=16, fontweight='bold', color='black')

    # Create the heatmap without showing the color bar
        sns.heatmap(cm, annot=False, cmap="Pastel2", cbar=False)

    # Add axis labels and title
    plt.xlabel("True Labels", fontweight="bold", fontsize=19, color='darkblue')
    plt.ylabel("Predicted Labels", fontweight="bold", fontsize=19, color='darkblue')

    # Set custom tick labels for x and y axes
    plt.xticks(np.arange(len(labels)) + 0.5, labels, fontweight="bold", fontsize=16)
    plt.yticks(np.arange(len(labels)) + 0.5, labels, fontweight="bold", fontsize=16)
    
    # Manually set the color for the "Normal" label
    x_ticks = plt.gca().get_xticklabels()
    x_ticks[labels.index("Attack Free")].set_color('Green')
    y_ticks = plt.gca().get_yticklabels()
    y_ticks[labels.index("Attack Free")].set_color('Green')
    
    # Add a red square box around "DoS," "Fuzz," and "Replay" labels
    rect = plt.Rectangle((labels.index("DoS") - 0.02, labels.index("DoS") - 0.02), 3, 3, fill=False, edgecolor='red', linewidth=2)
    plt.gca().add_patch(rect)

    plt.show()

# %%
labels = ["Attack Free", "DoS", "Fuzz", "Replay"]
plot_confusion_matrix_with_percentages(y_test, y_pred, labels)

# %%
from sklearn.metrics import classification_report
class_names = ["Normal", "DoS", "Fuzz", "Replay"]
print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.89      0.86      0.88       969
#          DoS       0.76      0.78      0.77       969
#         Fuzz       0.93      0.95      0.94       170
#       Replay       0.86      0.87      0.87       970
#
#     accuracy                           0.84      3078
#    macro avg       0.86      0.86      0.86      3078
# weighted avg       0.84      0.84      0.84      3078

# %%
def calculate_metrics(y_true, y_pred):
    total_samples = len(y_true)
    total_negative_samples = 0
    false_alarms = 0
    incorrect_samples = 0

    for true_label, predicted_label in zip(y_true, y_pred):
        if true_label != predicted_label:
            incorrect_samples += 1

        if true_label == 0:
            total_negative_samples += 1
            if predicted_label == 1:
                false_alarms += 1

    error_rate = incorrect_samples / total_samples
    false_alarm_rate = false_alarms / total_negative_samples if total_negative_samples != 0 else 0

    print("Error Rate:", error_rate)
    print("False Alarm Rate:", false_alarm_rate)

# %%
calculate_metrics(y_test, y_pred)
# Out:
# Error Rate: 0.1572449642625081
# False Alarm Rate: 0.1238390092879257

# %%
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc, roc_auc_score


target= ["Normal", "DoS", "Fuzz", "Replay"]

# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (15, 10))
sns.set(font_scale=1.5) #edited as suggested

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)

    for (idx, c_label) in enumerate(target):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)


print('ROC AUC score:', multiclass_roc_auc_score(y_test, y_pred))

c_ax.set_xlabel('False Positive Rate(TPR)', fontname="Times New Roman", size=18, fontweight="bold", color='darkblue')
c_ax.set_ylabel('True Positive Rate (FPR)', fontname="Times New Roman", size=18, fontweight="bold", color='darkblue')
#c_ax.text(0.16, -0.22, 'Fig. 6. (c) RUC Score CNN Multiclass Class Classification', fontname="Times New Roman",fontsize=25,fontweight="bold")
c_ax.legend(loc="lower right")
# Out:
# ROC AUC score: 0.9036294039056397

# %%
def plot_confusion_matrix_with_percentages_bin(y_pred, y_test, labels):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Convert the counts to percentages along columns (category-wise percentages)
    col_sums = cm.sum(axis=1)
    cm_percentages = cm / col_sums[:, np.newaxis] * 100
    
    # Create a heatmap with seaborn
    plt.figure(figsize=(8, 7))

    # Plot the confusion matrix as a heatmap with annotations for both numbers and percentages
    for i in range(len(cm)):
        for j in range(len(cm)):
            # Add actual numbers as text in the center of each cell
            plt.text(j + 0.5, i + 0.5, str(cm[i, j]), ha='center', va='center', fontsize=25, fontweight='bold', color='black')
            # Add percentages as text on top of the actual numbers
            plt.text(j + 0.5, i + 0.65, f'{cm_percentages[i, j]:.2f}%', ha='center', va='center', fontsize=25, fontweight='bold', color='black')

    # Create the heatmap without showing the color bar
    sns.heatmap(cm, annot=False, cmap="Pastel2", cbar=False)

    # Add axis labels and title
    plt.xlabel("Predicted Class", fontweight="bold", fontsize=19, color='darkblue')
    plt.ylabel("Actual Class", fontweight="bold", fontsize=19, color='darkblue')

    # Set custom tick labels for x and y axes
    plt.xticks(np.arange(len(labels)) + 0.5, labels, fontweight="bold", fontsize=16)
    plt.yticks(np.arange(len(labels)) + 0.5, labels, fontweight="bold", fontsize=16)
    
    # Manually set the color for the "Attack Free" label
    x_ticks = plt.gca().get_xticklabels()
    x_ticks[labels.index("Attack Free")].set_color('Green')
    y_ticks = plt.gca().get_yticklabels()
    y_ticks[labels.index("Attack Free")].set_color('Green')
    
    # Manually set the color for the "Attack" label
    x_ticks = plt.gca().get_xticklabels()
    x_ticks[labels.index("Attack")].set_color('Red')
    y_ticks = plt.gca().get_yticklabels()
    y_ticks[labels.index("Attack")].set_color('Red')

    plt.show()

    # Get the classification report
    report = classification_report(y_test, y_pred, target_names=labels)
    
    # Compute AUC
    auc_score = roc_auc_score(y_test, y_pred)
    print(f"\nAUC Score: {auc_score:.2f}")

    print("\nClassification Report:")
    print(report)

# %%
y_pred_bin = y_pred
y_test_bin = y_test
# Replace values greater than 0 with 1
y_pred_bin[y_pred_bin > 0] = 1
# Replace values greater than 0 with 1
y_test_bin[y_test_bin > 0] = 1
# Define labels for the confusion matrix
labels = ["Attack Free", "Attack"]
#y_pred_bin = np.concatenate((y_pred_bin, np.zeros(1200)))
#y_test_bin = np.concatenate((y_test_bin, np.zeros(1200)))

# %%
plot_confusion_matrix_with_percentages_bin(y_test_bin, y_pred_bin, labels)
# Out:
# AUC Score: 0.92
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Attack Free       0.86      0.89      0.88       937
#       Attack       0.95      0.94      0.94      2141
#
#     accuracy                           0.92      3078
#    macro avg       0.91      0.92      0.91      3078
# weighted avg       0.92      0.92      0.92      3078

# %%
class_names = ["Attack Free", "Attack"]
print(classification_report(y_pred_bin, y_test_bin, target_names=class_names))
# Calculate ROC AUC score
roc_auc = roc_auc_score(y_test_bin, y_pred_bin)
print(f'ROC AUC Score: {roc_auc:.2f}')
# Out:
#               precision    recall  f1-score   support
#
#  Attack Free       0.86      0.89      0.88       937
#       Attack       0.95      0.94      0.94      2141
#
#     accuracy                           0.92      3078
#    macro avg       0.91      0.92      0.91      3078
# weighted avg       0.92      0.92      0.92      3078
#
# ROC AUC Score: 0.91

# %%
calculate_metrics(y_pred_bin, y_test_bin)
# Out:
# Error Rate: 0.07602339181286549
# False Alarm Rate: 0.10779082177161152
