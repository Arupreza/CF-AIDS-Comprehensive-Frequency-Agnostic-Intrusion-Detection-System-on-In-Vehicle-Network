# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import torch.optim as optim
from torch.optim.lr_scheduler import ExponentialLR
import datetime
import time
import os
import seaborn as sns
scaler = MinMaxScaler()

# %%
# setting device on GPU if available, else CPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda:0
#
# NVIDIA GeForce GTX 1650
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
def data_pep(df, feat_col_idx, target_col_idx, seq_len=10):
    X_out = []
    y_out = []
    X = df[:, feat_col_idx]
    y = df[:, target_col_idx]

    start_idx = 0
    end_idx = seq_len
    length = len(df)

    while end_idx <= length:
        X_seq = X[start_idx:end_idx].reshape(seq_len, -1, 1)
        y_seq = y[end_idx-1]
        X_out.append(X_seq)
        y_out.append(y_seq)
        start_idx += seq_len
        end_idx += seq_len

    X_out = np.array(X_out)
    y_out = np.array(y_out)
    
    return X_out, y_out

# %%
from torch.utils.data import DataLoader, Dataset

class MyDataset(Dataset):
    def __init__(self, x, y):
        self.x = torch.from_numpy(x).float()
        self.y = torch.from_numpy(y).long()

    def __getitem__(self, index):
        return self.x[index], self.y[index]

    def __len__(self):
        return len(self.x)

# %%
gabor_out = "C:/Users/rezan/Arupreza/Gabor Assets/Gabor_Data/Deep Learning Input/"

# %%
Kia_train_G = pd.read_csv(gabor_out + 'Tesla_train_G____1.csv')
Kia_test_G = pd.read_csv(gabor_out + 'Tesla_test_G____1.csv')
Kia_val_G = pd.read_csv(gabor_out + 'Tesla_val_G____1.csv')

# %%
print("Kia_Normal_G Data Shape: ", Kia_train_G.shape)
print("Kia_Fuzz_G Data Shape: ", Kia_test_G.shape)
print("Kia_DoS_G Data Shape: ", Kia_val_G.shape)
# Out:
# Kia_Normal_G Data Shape:  (3720080, 3)
# Kia_Fuzz_G Data Shape:  (1077780, 3)
# Kia_DoS_G Data Shape:  (1077780, 3)

# %%
X_Kia_train_G, y_Kia_train_G = data_pep(np.array(Kia_train_G), feat_col_idx=[0, 1], target_col_idx=2, seq_len=100)
X_Kia_test_G, y_Kia_test_G = data_pep(np.array(Kia_test_G), feat_col_idx=[0, 1], target_col_idx=2, seq_len=100)
X_Kia_val_G, y_Kia_val_G = data_pep(np.array(Kia_val_G), feat_col_idx=[0, 1], target_col_idx=2, seq_len=100)

# %%
print(X_Kia_train_G[0].shape)
print(y_Kia_train_G[0].shape)

print(X_Kia_test_G[0].shape)
print(y_Kia_test_G[0].shape)

print(X_Kia_val_G[0].shape)
print(y_Kia_val_G[0].shape)
# Out:
# (100, 2, 1)
# ()
# (100, 2, 1)
# ()
# (100, 2, 1)
# ()

# %%
train_dataset = MyDataset(X_Kia_train_G, y_Kia_train_G)
val_dataset = MyDataset(X_Kia_test_G, y_Kia_test_G)
test_dataset = MyDataset(X_Kia_val_G, y_Kia_val_G)

# %%
# Hyper-parameters 
# input_size = 784 # 28x28
num_classes = 4
num_epochs = 100
batch_size = 64
learning_rate = 0.0001

input_size = 2
sequence_length = 100
hidden_size = 128
num_layers = 5

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
# get some random training images
dataiter = iter(train_loader)
sets, labels = next(dataiter)

print(sets[0].shape)
print(sets[0].shape)

print(sets.shape)
print(sets.ndim)
# Out:
# torch.Size([100, 2, 1])
# torch.Size([100, 2, 1])
# torch.Size([64, 100, 2, 1])
# 4

# %%
# Fully connected neural network with one hidden layer
class GRU_Model(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(GRU_Model, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        # -> x needs to be: (batch_size, seq, input_size)
        
        # or:
        #self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        #self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
        
    def forward(self, x):
        # Set initial hidden states (and cell states for LSTM)
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        
        # Forward propagate RNN
        out, _ = self.gru(x, h0)  
        
        # Decode the hidden state of the last time step
        out = out[:, -1, :]
        # out: (n, 128)
         
        out = self.fc(out)
        #out = F.relu(out)
        # out: (n, 10)
        return out

# %%
from torchviz import make_dot

netD = GRU_Model(input_size, hidden_size, num_layers, num_classes)
# Generate a random input tensor with shape (batch_size, sequence_length, input_size)
input_tensor = torch.randn(batch_size, sequence_length, input_size)

# If your model is on GPU, move the input tensor to GPU as well
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
netD = netD.to(device)
input_tensor = input_tensor.to(device)

# Forward pass and visualize
out = netD(input_tensor)
make_dot(out, params=dict(list(netD.named_parameters())))

# %%
model = GRU_Model(input_size, hidden_size, num_layers, num_classes).to(device)

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def train_model(model, train_loader, valid_loader, criterion, optimizer, num_epochs, patience):
    train_losses = []
    valid_losses = []
    best_loss = float('inf')
    best_epoch = 0
    n_no_improvement = 0
    n_total_steps = len(train_loader)
    model_path = 'Tesla_Lisa1.pt'  # Path to save the model

    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path))

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    for epoch in range(num_epochs):
        # Training
        train_loss = 0.0
        model.train()
        for i, (images, labels) in enumerate(train_loader):
            images = images.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

            if (i + 1) % 100 == 0:
                print(f'Train: Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{n_total_steps}], Loss: {loss.item():.4f}')

        train_loss /= len(train_loader)
        train_losses.append(train_loss)

        # Validation
        valid_loss = 0.0
        model.eval()
        with torch.no_grad():
            for images, labels in valid_loader:
                images = images.reshape(-1, sequence_length, input_size).to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                valid_loss += loss.item()

            valid_loss /= len(valid_loader)
            valid_losses.append(valid_loss)

            print(f'Valid: Epoch [{epoch + 1}/{num_epochs}], Loss: {valid_loss:.4f}')

            if valid_loss < best_loss:
                best_loss = valid_loss
                best_epoch = epoch
                n_no_improvement = 0

                # Save the model
                torch.save(model.state_dict(), model_path)

            else:
                n_no_improvement += 1

            if n_no_improvement >= patience:
                print(f'Early stopping: no improvement for {patience} epochs.')
                break

    return train_losses, valid_losses, best_loss, best_epoch

# %%
#train_losses, valid_losses, best_loss, best_epoch = train_model(model, train_loader, valid_loader, criterion, optimizer, num_epochs=500, patience=10)
# Out:
# Train: Epoch [1/500], Step [100/582], Loss: 1.2550
# Train: Epoch [1/500], Step [200/582], Loss: 0.6154
# Train: Epoch [1/500], Step [300/582], Loss: 0.4917
# Train: Epoch [1/500], Step [400/582], Loss: 0.5921
# Train: Epoch [1/500], Step [500/582], Loss: 0.3694
# Valid: Epoch [1/500], Loss: 0.2864
# Train: Epoch [2/500], Step [100/582], Loss: 0.2489
# Train: Epoch [2/500], Step [200/582], Loss: 0.2923
# Train: Epoch [2/500], Step [300/582], Loss: 0.2849
# Train: Epoch [2/500], Step [400/582], Loss: 0.3395
# Train: Epoch [2/500], Step [500/582], Loss: 0.1124
# Valid: Epoch [2/500], Loss: 0.2120
# Train: Epoch [3/500], Step [100/582], Loss: 0.1800
# Train: Epoch [3/500], Step [200/582], Loss: 0.2273
# Train: Epoch [3/500], Step [300/582], Loss: 0.1202
# Train: Epoch [3/500], Step [400/582], Loss: 0.1778
# Train: Epoch [3/500], Step [500/582], Loss: 0.0891
# Valid: Epoch [3/500], Loss: 0.1672
# Train: Epoch [4/500], Step [100/582], Loss: 0.1666
# Train: Epoch [4/500], Step [200/582], Loss: 0.2425
# Train: Epoch [4/500], Step [300/582], Loss: 0.2226
# Train: Epoch [4/500], Step [400/582], Loss: 0.2297
# Train: Epoch [4/500], Step [500/582], Loss: 0.1592
# Valid: Epoch [4/500], Loss: 0.1424
# Train: Epoch [5/500], Step [100/582], Loss: 0.2124
# Train: Epoch [5/500], Step [200/582], Loss: 0.1905
# Train: Epoch [5/500], Step [300/582], Loss: 0.2196
# Train: Epoch [5/500], Step [400/582], Loss: 0.1476
# Train: Epoch [5/500], Step [500/582], Loss: 0.1407
# Valid: Epoch [5/500], Loss: 0.1489
# Train: Epoch [6/500], Step [100/582], Loss: 0.0953
# Train: Epoch [6/500], Step [200/582], Loss: 0.1803
# Train: Epoch [6/500], Step [300/582], Loss: 0.1357
# Train: Epoch [6/500], Step [400/582], Loss: 0.1586
# Train: Epoch [6/500], Step [500/582], Loss: 0.1474
# Valid: Epoch [6/500], Loss: 0.2500
# Train: Epoch [7/500], Step [100/582], Loss: 0.2095
# Train: Epoch [7/500], Step [200/582], Loss: 0.1265
# Train: Epoch [7/500], Step [300/582], Loss: 0.2729
# Train: Epoch [7/500], Step [400/582], Loss: 0.2341
# Train: Epoch [7/500], Step [500/582], Loss: 0.1715
# Valid: Epoch [7/500], Loss: 0.1539
# Train: Epoch [8/500], Step [100/582], Loss: 0.0975
# Train: Epoch [8/500], Step [200/582], Loss: 0.1284
# Train: Epoch [8/500], Step [300/582], Loss: 0.1953
# Train: Epoch [8/500], Step [400/582], Loss: 0.0908
# Train: Epoch [8/500], Step [500/582], Loss: 0.1362
# Valid: Epoch [8/500], Loss: 0.1258
# Train: Epoch [9/500], Step [100/582], Loss: 0.1083
# Train: Epoch [9/500], Step [200/582], Loss: 0.1256
# Train: Epoch [9/500], Step [300/582], Loss: 0.1619
# Train: Epoch [9/500], Step [400/582], Loss: 0.1937
# Train: Epoch [9/500], Step [500/582], Loss: 0.3069
# Valid: Epoch [9/500], Loss: 0.1144
# Train: Epoch [10/500], Step [100/582], Loss: 0.1511
# Train: Epoch [10/500], Step [200/582], Loss: 0.1161
# Train: Epoch [10/500], Step [300/582], Loss: 0.1306
# Train: Epoch [10/500], Step [400/582], Loss: 0.1292
# Train: Epoch [10/500], Step [500/582], Loss: 0.1349
# Valid: Epoch [10/500], Loss: 0.1177
# Train: Epoch [11/500], Step [100/582], Loss: 0.1581
# Train: Epoch [11/500], Step [200/582], Loss: 0.2594
# Train: Epoch [11/500], Step [300/582], Loss: 0.1839
# Train: Epoch [11/500], Step [400/582], Loss: 0.1151
# Train: Epoch [11/500], Step [500/582], Loss: 0.1279
# Valid: Epoch [11/500], Loss: 0.1104
# Train: Epoch [12/500], Step [100/582], Loss: 0.1513
# Train: Epoch [12/500], Step [200/582], Loss: 0.2023
# Train: Epoch [12/500], Step [300/582], Loss: 0.0716
# Train: Epoch [12/500], Step [400/582], Loss: 0.0779
# Train: Epoch [12/500], Step [500/582], Loss: 0.0585
# Valid: Epoch [12/500], Loss: 0.1085
# Train: Epoch [13/500], Step [100/582], Loss: 0.1293
# Train: Epoch [13/500], Step [200/582], Loss: 0.1416
# Train: Epoch [13/500], Step [300/582], Loss: 0.2367
# Train: Epoch [13/500], Step [400/582], Loss: 0.0491
# Train: Epoch [13/500], Step [500/582], Loss: 0.1422
# Valid: Epoch [13/500], Loss: 0.0992
# Train: Epoch [14/500], Step [100/582], Loss: 0.1679
# Train: Epoch [14/500], Step [200/582], Loss: 0.0690
# Train: Epoch [14/500], Step [300/582], Loss: 0.1734
# Train: Epoch [14/500], Step [400/582], Loss: 0.0706
# Train: Epoch [14/500], Step [500/582], Loss: 0.0323
# Valid: Epoch [14/500], Loss: 0.0716
# Train: Epoch [15/500], Step [100/582], Loss: 0.0228
# Train: Epoch [15/500], Step [200/582], Loss: 0.0272
# Train: Epoch [15/500], Step [300/582], Loss: 0.1308
# Train: Epoch [15/500], Step [400/582], Loss: 0.0529
# Train: Epoch [15/500], Step [500/582], Loss: 0.0583
# Valid: Epoch [15/500], Loss: 0.0460
# Train: Epoch [16/500], Step [100/582], Loss: 0.0286
# Train: Epoch [16/500], Step [200/582], Loss: 0.0481
# Train: Epoch [16/500], Step [300/582], Loss: 0.0983
# Train: Epoch [16/500], Step [400/582], Loss: 0.0362
# Train: Epoch [16/500], Step [500/582], Loss: 0.0333
# Valid: Epoch [16/500], Loss: 0.0351
# Train: Epoch [17/500], Step [100/582], Loss: 0.0384
# Train: Epoch [17/500], Step [200/582], Loss: 0.0893
# Train: Epoch [17/500], Step [300/582], Loss: 0.0237
# Train: Epoch [17/500], Step [400/582], Loss: 0.0118
# Train: Epoch [17/500], Step [500/582], Loss: 0.0088
# Valid: Epoch [17/500], Loss: 0.0286
# Train: Epoch [18/500], Step [100/582], Loss: 0.0319
# Train: Epoch [18/500], Step [200/582], Loss: 0.0459
# Train: Epoch [18/500], Step [300/582], Loss: 0.0771
# Train: Epoch [18/500], Step [400/582], Loss: 0.0120
# Train: Epoch [18/500], Step [500/582], Loss: 0.0258
# Valid: Epoch [18/500], Loss: 0.0301
# Train: Epoch [19/500], Step [100/582], Loss: 0.0693
# Train: Epoch [19/500], Step [200/582], Loss: 0.0287
# Train: Epoch [19/500], Step [300/582], Loss: 0.0480
# Train: Epoch [19/500], Step [400/582], Loss: 0.0047
# Train: Epoch [19/500], Step [500/582], Loss: 0.0608
# Valid: Epoch [19/500], Loss: 0.0285
# Train: Epoch [20/500], Step [100/582], Loss: 0.0990
# Train: Epoch [20/500], Step [200/582], Loss: 0.0612
# Train: Epoch [20/500], Step [300/582], Loss: 0.0501
# Train: Epoch [20/500], Step [400/582], Loss: 0.0117
# Train: Epoch [20/500], Step [500/582], Loss: 0.1076
# Valid: Epoch [20/500], Loss: 0.0785
# Train: Epoch [21/500], Step [100/582], Loss: 0.0306
# Train: Epoch [21/500], Step [200/582], Loss: 0.0077
# Train: Epoch [21/500], Step [300/582], Loss: 0.0306
# Train: Epoch [21/500], Step [400/582], Loss: 0.0555
# Train: Epoch [21/500], Step [500/582], Loss: 0.0900
# Valid: Epoch [21/500], Loss: 0.1176
# Train: Epoch [22/500], Step [100/582], Loss: 0.0259
# Train: Epoch [22/500], Step [200/582], Loss: 0.0091
# Train: Epoch [22/500], Step [300/582], Loss: 0.0555
# Train: Epoch [22/500], Step [400/582], Loss: 0.0016
# Train: Epoch [22/500], Step [500/582], Loss: 0.0043
# Valid: Epoch [22/500], Loss: 0.0195
# Train: Epoch [23/500], Step [100/582], Loss: 0.0072
# Train: Epoch [23/500], Step [200/582], Loss: 0.0825
# Train: Epoch [23/500], Step [300/582], Loss: 0.0162
# Train: Epoch [23/500], Step [400/582], Loss: 0.0082
# Train: Epoch [23/500], Step [500/582], Loss: 0.0023
# Valid: Epoch [23/500], Loss: 0.0469
# Train: Epoch [24/500], Step [100/582], Loss: 0.0025
# Train: Epoch [24/500], Step [200/582], Loss: 0.0382
# Train: Epoch [24/500], Step [300/582], Loss: 0.0150
# Train: Epoch [24/500], Step [400/582], Loss: 0.0184
# Train: Epoch [24/500], Step [500/582], Loss: 0.0032
# Valid: Epoch [24/500], Loss: 0.0198
# Train: Epoch [25/500], Step [100/582], Loss: 0.1349
# Train: Epoch [25/500], Step [200/582], Loss: 0.0010
# Train: Epoch [25/500], Step [300/582], Loss: 0.0018
# Train: Epoch [25/500], Step [400/582], Loss: 0.0032
# Train: Epoch [25/500], Step [500/582], Loss: 0.0031
# Valid: Epoch [25/500], Loss: 0.0142
# Train: Epoch [26/500], Step [100/582], Loss: 0.0066
# Train: Epoch [26/500], Step [200/582], Loss: 0.0050
# Train: Epoch [26/500], Step [300/582], Loss: 0.0608
# Train: Epoch [26/500], Step [400/582], Loss: 0.0018
# Train: Epoch [26/500], Step [500/582], Loss: 0.0028
# Valid: Epoch [26/500], Loss: 0.0117
# Train: Epoch [27/500], Step [100/582], Loss: 0.0014
# Train: Epoch [27/500], Step [200/582], Loss: 0.0102
# Train: Epoch [27/500], Step [300/582], Loss: 0.0146
# Train: Epoch [27/500], Step [400/582], Loss: 0.0408
# Train: Epoch [27/500], Step [500/582], Loss: 0.0340
# Valid: Epoch [27/500], Loss: 0.0096
# Train: Epoch [28/500], Step [100/582], Loss: 0.0024
# Train: Epoch [28/500], Step [200/582], Loss: 0.0159
# Train: Epoch [28/500], Step [300/582], Loss: 0.0036
# Train: Epoch [28/500], Step [400/582], Loss: 0.0107
# Train: Epoch [28/500], Step [500/582], Loss: 0.0540
# Valid: Epoch [28/500], Loss: 0.0093
# Train: Epoch [29/500], Step [100/582], Loss: 0.0389
# Train: Epoch [29/500], Step [200/582], Loss: 0.0104
# Train: Epoch [29/500], Step [300/582], Loss: 0.0306
# Train: Epoch [29/500], Step [400/582], Loss: 0.2495
# Train: Epoch [29/500], Step [500/582], Loss: 0.0337
# Valid: Epoch [29/500], Loss: 0.0081
# Train: Epoch [30/500], Step [100/582], Loss: 0.0126
# Train: Epoch [30/500], Step [200/582], Loss: 0.0175
# Train: Epoch [30/500], Step [300/582], Loss: 0.0039
# Train: Epoch [30/500], Step [400/582], Loss: 0.0006
# Train: Epoch [30/500], Step [500/582], Loss: 0.0211
# Valid: Epoch [30/500], Loss: 0.0189
# Train: Epoch [31/500], Step [100/582], Loss: 0.0062
# Train: Epoch [31/500], Step [200/582], Loss: 0.0042
# Train: Epoch [31/500], Step [300/582], Loss: 0.0109
# Train: Epoch [31/500], Step [400/582], Loss: 0.0257
# Train: Epoch [31/500], Step [500/582], Loss: 0.0137
# Valid: Epoch [31/500], Loss: 0.0122
# Train: Epoch [32/500], Step [100/582], Loss: 0.0032
# Train: Epoch [32/500], Step [200/582], Loss: 0.0383
# Train: Epoch [32/500], Step [300/582], Loss: 0.0075
# Train: Epoch [32/500], Step [400/582], Loss: 0.0026
# Train: Epoch [32/500], Step [500/582], Loss: 0.0043
# Valid: Epoch [32/500], Loss: 0.0076
# Train: Epoch [33/500], Step [100/582], Loss: 0.0215
# Train: Epoch [33/500], Step [200/582], Loss: 0.0136
# Train: Epoch [33/500], Step [300/582], Loss: 0.0037
# Train: Epoch [33/500], Step [400/582], Loss: 0.0038
# Train: Epoch [33/500], Step [500/582], Loss: 0.0003
# Valid: Epoch [33/500], Loss: 0.0189
# Train: Epoch [34/500], Step [100/582], Loss: 0.0080
# Train: Epoch [34/500], Step [200/582], Loss: 0.0037
# Train: Epoch [34/500], Step [300/582], Loss: 0.0273
# Train: Epoch [34/500], Step [400/582], Loss: 0.1813
# Train: Epoch [34/500], Step [500/582], Loss: 0.0009
# Valid: Epoch [34/500], Loss: 0.0080
# Train: Epoch [35/500], Step [100/582], Loss: 0.0030
# Train: Epoch [35/500], Step [200/582], Loss: 0.0531
# Train: Epoch [35/500], Step [300/582], Loss: 0.0039
# Train: Epoch [35/500], Step [400/582], Loss: 0.0006
# Train: Epoch [35/500], Step [500/582], Loss: 0.0036
# Valid: Epoch [35/500], Loss: 0.0069
# Train: Epoch [36/500], Step [100/582], Loss: 0.0034
# Train: Epoch [36/500], Step [200/582], Loss: 0.0005
# Train: Epoch [36/500], Step [300/582], Loss: 0.0436
# Train: Epoch [36/500], Step [400/582], Loss: 0.0224
# Train: Epoch [36/500], Step [500/582], Loss: 0.0022
# Valid: Epoch [36/500], Loss: 0.0070
# Train: Epoch [37/500], Step [100/582], Loss: 0.0289
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 train_losses, valid_losses, best_loss, best_epoch = train_model(model, train_loader, valid_loader, criterion, optimizer, num_epochs=500, patience=10)
#
# Cell In[18], line 27, in train_model(model, train_loader, valid_loader, criterion, optimizer, num_epochs, patience)
#      24 loss = criterion(outputs, labels)
#      26 optimizer.zero_grad()
# ---> 27 loss.backward()
#      28 optimizer.step()
#      30 train_loss += loss.item()
#
# File D:\Works\lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File D:\Works\lib\site-packages\torch\autograd\__init__.py:193, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     189 inputs = (inputs,) if isinstance(inputs, torch.Tensor) else \
#     190     tuple(inputs) if inputs is not None else tuple()
#     192 grad_tensors_ = _tensor_or_tensors_to_tuple(grad_tensors, len(tensors))
# --> 193 grad_tensors_ = _make_grads(tensors, grad_tensors_, is_grads_batched=False)
#     194 if retain_graph is None:
#     195     retain_graph = create_graph
#
# File D:\Works\lib\site-packages\torch\autograd\__init__.py:89, in _make_grads(outputs, grads, is_grads_batched)
#      87     if out.numel() != 1:
#      88         raise RuntimeError("grad can be implicitly created only for scalar outputs")
# ---> 89     new_grads.append(torch.ones_like(out, memory_format=torch.preserve_format))
#      90 else:
#      91     new_grads.append(None)
#
# KeyboardInterrupt:

# %%
def test_model(model, test_loader):
    model = model.to(device)  # Move the model to the appropriate device
    model.eval()
    with torch.no_grad():
        predictions = []
        labels = []
        for images, batch_labels in test_loader:
            images = images.reshape(-1, sequence_length, input_size).to(device)
            batch_labels = batch_labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            predictions.append(predicted.cpu().numpy())
            labels.append(batch_labels.cpu().numpy())

        predictions = np.concatenate(predictions)
        labels = np.concatenate(labels)
        acc = 100.0 * np.sum(predictions == labels) / len(labels)
        print(f'Accuracy of the network on the test set: {acc:.4f} %')
        return predictions, labels

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GRU_Model(input_size, hidden_size, num_layers, num_classes)
model.load_state_dict(torch.load('Tesla_Lisa1.pt', map_location=device))

# Move the test_loader to the appropriate device
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
# Replace 'test_dataset' with your actual test dataset

test_predictions, test_labels = test_model(model, test_loader)
# Out:
# Accuracy of the network on the test set: 99.7216 %

# %%
y_pred = test_predictions
y_test = test_labels

# %%
from sklearn.metrics import confusion_matrix

#Get the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print(cf_matrix)
# Out:
# [[3142    0    0    3]
#  [   0 1822    1    0]
#  [   0    3 4212    0]
#  [  22    1    0 1571]]

# %%
def plot_confusion_matrix_with_percentages(y_test, y_pred, labels):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Convert the counts to percentages along rows (category-wise percentages)
    row_sums = cm.sum(axis=1)
    cm_percentages = cm / row_sums[:, np.newaxis] * 100
    
    # Create a heatmap with seaborn
    plt.figure(figsize=(8, 7))

    # Plot the confusion matrix as a heatmap with annotations for both numbers and percentages
    # Plot the confusion matrix as a heatmap with annotations for both numbers and percentages
    for i in range(len(cm)):
        for j in range(len(cm)):
            # Add actual numbers as text in the center of each cell
            plt.text(j + 0.5, i + 0.5, str(cm[i, j]), ha='center', va='center', fontsize=16, fontweight='bold', color='black')
            # Add percentages as text on top of the actual numbers
            plt.text(j + 0.5, i + 0.65, f'{cm_percentages[i, j]:.2f}%', ha='center', va='center', fontsize=16, fontweight='bold', color='black')

    # Create the heatmap without showing the color bar
        sns.heatmap(cm, annot=False, cmap="Pastel2", cbar=False)

    # Add axis labels and title
    plt.xlabel("True Labels", fontweight="bold", fontsize=19, color='darkblue')
    plt.ylabel("Predicted Labels", fontweight="bold", fontsize=19, color='darkblue')

    # Set custom tick labels for x and y axes
    plt.xticks(np.arange(len(labels)) + 0.5, labels, fontweight="bold", fontsize=16)
    plt.yticks(np.arange(len(labels)) + 0.5, labels, fontweight="bold", fontsize=16)
    
    # Manually set the color for the "Normal" label
    x_ticks = plt.gca().get_xticklabels()
    x_ticks[labels.index("Attack Free")].set_color('Green')
    y_ticks = plt.gca().get_yticklabels()
    y_ticks[labels.index("Attack Free")].set_color('Green')
    
    # Add a red square box around "DoS," "Fuzz," and "Replay" labels
    rect = plt.Rectangle((labels.index("DoS") - 0.02, labels.index("DoS") - 0.02), 3, 3, fill=False, edgecolor='red', linewidth=2)
    plt.gca().add_patch(rect)

    plt.show()

# %%
labels = ["Attack Free", "DoS", "Fuzz", "Replay"]
plot_confusion_matrix_with_percentages(y_test, y_pred, labels)

# %%
from sklearn.metrics import classification_report
class_names = ["Normal", "DoS", "Fuzz", "Replay"]
print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.99      1.00      1.00      3145
#          DoS       1.00      1.00      1.00      1823
#         Fuzz       1.00      1.00      1.00      4215
#       Replay       1.00      0.99      0.99      1594
#
#     accuracy                           1.00     10777
#    macro avg       1.00      1.00      1.00     10777
# weighted avg       1.00      1.00      1.00     10777

# %%
def calculate_metrics(y_true, y_pred):
    total_samples = len(y_true)
    total_negative_samples = 0
    false_alarms = 0
    incorrect_samples = 0

    for true_label, predicted_label in zip(y_true, y_pred):
        if true_label != predicted_label:
            incorrect_samples += 1

        if true_label == 0:
            total_negative_samples += 1
            if predicted_label == 1:
                false_alarms += 1

    error_rate = incorrect_samples / total_samples
    false_alarm_rate = false_alarms / total_negative_samples if total_negative_samples != 0 else 0

    print("Error Rate:", error_rate)
    print("False Alarm Rate:", false_alarm_rate)

# %%
calculate_metrics(y_test, y_pred)
# Out:
# Error Rate: 0.002783706040642108
# False Alarm Rate: 0.0

# %%
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc, roc_auc_score


target= ["Attack Free", "DoS", "Fuzz", "Replay"]

# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (15, 10))
sns.set(font_scale=1.5) #edited as suggested

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)

    for (idx, c_label) in enumerate(target):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)


print('ROC AUC score:', multiclass_roc_auc_score(y_test, y_pred))

c_ax.set_xlabel('False Positive Rate(TPR)', fontname="Times New Roman", size=18, fontweight="bold", color='darkblue')
c_ax.set_ylabel('True Positive Rate (FPR)', fontname="Times New Roman", size=18, fontweight="bold", color='darkblue')
#c_ax.text(0.16, -0.22, 'Fig. 6. (c) RUC Score CNN Multiclass Class Classification', fontname="Times New Roman",fontsize=25,fontweight="bold")
c_ax.legend(loc="lower right")
# Out:
# ROC AUC score: 0.9974435368946639

# %% [markdown]
# # Test On Lower Injection

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GRU_Model(input_size, hidden_size, num_layers, num_classes)
model.load_state_dict(torch.load('Tesla_Lisa.pt', map_location=device))

# Move the test_loader to the appropriate device
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
# Replace 'test_dataset' with your actual test dataset

test_predictions, test_labels = test_model(model, test_loader)
# Out:
# Accuracy of the network on the test set: 15.6166 %

# %%
Tesla_V2_test_G = pd.read_csv(gabor_out + 'Tesla_V2_test_G____.csv')
Tesla_V2_val_G = pd.read_csv(gabor_out + 'Tesla_V2_val_G____.csv')

# %%
X_Kia_test_G, y_Kia_test_G = data_pep(np.array(Tesla_V2_test_G), feat_col_idx=[0, 1], target_col_idx=2, seq_len=100)
X_Kia_val_G, y_Kia_val_G = data_pep(np.array(Tesla_V2_val_G), feat_col_idx=[0, 1], target_col_idx=2, seq_len=100)

# %%
val_dataset = MyDataset(X_Kia_val_G, y_Kia_val_G)
test_dataset = MyDataset(X_Kia_test_G, y_Kia_test_G)

# %%
valid_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
# Move the test_loader to the appropriate device
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
# Replace 'test_dataset' with your actual test dataset

test_predictions, test_labels = test_model(model, test_loader)
# Out:
# Accuracy of the network on the test set: 54.5268 %

# %%
y_pred = test_predictions
y_test = test_labels

# %%
labels = ["Attack Free", "DoS", "Fuzz", "Replay"]
plot_confusion_matrix_with_percentages(y_test, y_pred, labels)

# %%
def plot_confusion_matrix_with_percentages_bin(y_test, y_pred, labels):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Convert the counts to percentages along rows (category-wise percentages)
    row_sums = cm.sum(axis=1)
    cm_percentages = cm / row_sums[:, np.newaxis] * 100
    
    # Create a heatmap with seaborn
    plt.figure(figsize=(8, 7))

    # Plot the confusion matrix as a heatmap with annotations for both numbers and percentages
    # Plot the confusion matrix as a heatmap with annotations for both numbers and percentages
    for i in range(len(cm)):
        for j in range(len(cm)):
            # Add actual numbers as text in the center of each cell
            plt.text(j + 0.5, i + 0.5, str(cm[i, j]), ha='center', va='center', fontsize=16, fontweight='bold', color='black')
            # Add percentages as text on top of the actual numbers
            plt.text(j + 0.5, i + 0.65, f'{cm_percentages[i, j]:.2f}%', ha='center', va='center', fontsize=16, fontweight='bold', color='black')

    # Create the heatmap without showing the color bar
    sns.heatmap(cm, annot=False, cmap="Pastel2", cbar=False)

    # Add axis labels and title
    plt.xlabel("True Labels", fontweight="bold", fontsize=19, color='darkblue')
    plt.ylabel("Predicted Labels", fontweight="bold", fontsize=19, color='darkblue')

    # Set custom tick labels for x and y axes
    plt.xticks(np.arange(len(labels)) + 0.5, labels, fontweight="bold", fontsize=16)
    plt.yticks(np.arange(len(labels)) + 0.5, labels, fontweight="bold", fontsize=16)
    
    # Manually set the color for the "Normal" label
    x_ticks = plt.gca().get_xticklabels()
    x_ticks[labels.index("Attack Free")].set_color('Green')
    y_ticks = plt.gca().get_yticklabels()
    y_ticks[labels.index("Attack Free")].set_color('Green')
    
    x_ticks = plt.gca().get_xticklabels()
    x_ticks[labels.index("Attack")].set_color('Red')
    y_ticks = plt.gca().get_yticklabels()
    y_ticks[labels.index("Attack")].set_color('Red')


    plt.show()

# %%
y_pred_bin = y_pred
y_test_bin = y_test

# %%
# Replace values greater than 0 with 1
y_pred_bin[y_pred_bin > 0] = 1
# Replace values greater than 0 with 1
y_test_bin[y_test_bin > 0] = 1

# %%
# Define labels for the confusion matrix
labels = ["Attack Free", "Attack"]

# %%
plot_confusion_matrix_with_percentages_bin(y_test_bin, y_pred_bin, labels)

# %%
class_names = ["Attack Free", "Attack"]
print(classification_report(y_pred_bin, y_test_bin, target_names=class_names))
# Calculate ROC AUC score
roc_auc = roc_auc_score(y_test_bin, y_pred_bin)
print(f'ROC AUC Score: {roc_auc:.2f}')
# Out:
#               precision    recall  f1-score   support
#
#  Attack Free       0.75      1.00      0.86      2365
#       Attack       1.00      0.78      0.87      3478
#
#     accuracy                           0.87      5843
#    macro avg       0.88      0.89      0.87      5843
# weighted avg       0.90      0.87      0.87      5843
#
# ROC AUC Score: 0.88

# %%
calculate_metrics(y_pred_bin, y_test_bin)
# Out:
# Error Rate: 0.13349306862912888
# False Alarm Rate: 0.0
